# %% [markdown]
# # Water Flood Segmentation

# %% [markdown]
# ### Import libraries

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tifffile as tiff
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import load_model

# %%
# Reproducability
def set_seed(seed=125):
    np.random.seed(seed)
    tf.random.set_seed(seed)

    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed(125)

# %%
BATCH_SIZE = 8
IMG_SIZE = 128

# %% [markdown]
# ### Data visualization

# %%
# Read the TIFF file
tif_path = 'data/images/0.tif'  
tif_image = tiff.imread(tif_path)

# Check the number of channels
num_channels = tif_image.shape[2]

# Plot each channel
for i in range(num_channels):
    plt.figure(figsize=(5, 5))
    plt.imshow(tif_image[:,:,i], cmap='gray')
    plt.title(f'Channel {i + 1}')
    plt.axis('off')
    plt.show()

# %%
tif_image.shape
# Out:
# (128, 128, 12)

# %%
#get the rgb channels
rgb_image = tif_image[:,:,1:4]
rgb_image = rgb_image[:,:,::-1]

# %%
# Normalize the image data to the range 0-1
rgb_image = rgb_image.astype(np.float32)
rgb_image -= rgb_image.min()  
rgb_image /= rgb_image.max()  
rgb_image *= 255.0

# Convert to uint8 type
rgb_image = rgb_image.astype(np.uint8)

# %%
# Plot the RGB image
plt.figure(figsize=(5, 5))
plt.imshow(rgb_image)
plt.title('RGB Image')
plt.axis('off')
plt.show()

# %%
# Read the image mask
png_path = 'data/labels/0.png'  
png_image = Image.open(png_path)

# Plot the image
plt.figure(figsize=(5, 5))
plt.imshow(png_image, cmap='gray')
plt.title('Image Mask')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Data preprocessing

# %%
# Paths
img_dir = "data/images"
label_dir = "data/labels"

# %%
# Get exact image base names 
image_files = {os.path.splitext(f)[0] for f in os.listdir(img_dir) if f.endswith('.tif')}
label_files = os.listdir(label_dir)

# Remove labels that don't match an image filename 
for label_file in label_files:
    base_name = os.path.splitext(label_file)[0]  # No splitting by underscore now
    if base_name not in image_files:
        os.remove(os.path.join(label_dir, label_file))

# %%
num_images = len([f for f in os.listdir(img_dir) if f.endswith('.tif')])
num_labels = len([f for f in os.listdir(label_dir) if f.endswith('.png')])

print(f"Number of images in '{img_dir}': {num_images}")
print(f"Number of labels in '{label_dir}': {num_labels}")
# Out:
# Number of images in 'data/images': 306
# Number of labels in 'data/labels': 306

# %%
# Function to compute per-channel max values
def get_max_of_channels(image_dir):
    image_maxs = np.full(12, -np.inf)
    for image_name in os.listdir(image_dir):
        if image_name.endswith('.tif'):
            image_path = os.path.join(image_dir, image_name)
            image = tiff.imread(image_path)
            image_maxs = np.maximum(image_maxs, image.max(axis=(0,1)))
    return image_maxs

# Function to compute per-channel min values
def get_min_of_channels(image_dir):
    image_mins = np.full(12, np.inf)
    for image_name in os.listdir(image_dir):
        if image_name.endswith('.tif'):
            image_path = os.path.join(image_dir, image_name)
            image = tiff.imread(image_path)
            image_mins = np.minimum(image_mins, image.min(axis=(0,1)))
    return image_mins

image_maxs = get_max_of_channels(img_dir)
image_mins = get_min_of_channels(img_dir)

print(image_maxs)
print(image_mins)
# Out:
# [ 6568.  9659. 11368. 12041. 15841. 15252. 14647.   255.  4245.  4287.
#    100.   111.]
# [-1.393e+03 -1.169e+03 -7.220e+02 -6.840e+02 -4.120e+02 -3.350e+02
#  -2.580e+02  6.400e+01 -9.999e+03  8.000e+00  1.000e+01  0.000e+00]

# %%
# Load and preprocess images
def load_image(image_path, label_path):
    image = tiff.imread(image_path).astype(np.float32)
    label = np.array(Image.open(label_path)).astype(np.float32)
    if label.max() > 1:
        label /= 255.0  # Normalize label if in range [0,255]
    return image, label

#normalize images
def preprocess_image(image):
    for i in range(image.shape[2]):
        min_val, max_val = image_mins[i], image_maxs[i]
        if max_val > min_val:  
            image[:, :, i] = (image[:, :, i] - min_val) / (max_val - min_val)
    return image.astype(np.float32)

def load_data(image_dir, label_dir):
    images, labels = [], []
    for image_name in os.listdir(image_dir):
        if image_name.endswith('.tif'):
            image_path = os.path.join(image_dir, image_name)
            label_path = os.path.join(label_dir, image_name.replace('.tif', '.png'))
            if os.path.exists(label_path):
                image, label = load_image(image_path, label_path)
                images.append(preprocess_image(image))
                labels.append(label)
    return np.array(images), np.array(labels)

images, labels = load_data(img_dir, label_dir)

# %%
print("After Normalization:")
print("Min pixel value:", images.min(), ", Max pixel value:", images.max())
# Out:
# After Normalization:
# Min pixel value: 0.0 , Max pixel value: 1.0

# %%
train_images, temp_images, train_labels, temp_labels = train_test_split(
    images, labels, test_size=0.2, random_state=125
)

val_images, test_images, val_labels, test_labels = train_test_split(
    temp_images, temp_labels, test_size=0.5, random_state=125
)

# Check the shapes
print(f"Training set: {train_images.shape}, {train_labels.shape}")
print(f"Validation set: {val_images.shape}, {val_labels.shape}")
print(f"Testing set: {test_images.shape}, {test_labels.shape}")
# Out:
# Training set: (244, 128, 128, 12), (244, 128, 128)
# Validation set: (31, 128, 128, 12), (31, 128, 128)
# Testing set: (31, 128, 128, 12), (31, 128, 128)

# %%
# Create datasets
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
train_dataset = train_dataset.shuffle(len(train_images)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels))
val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_dataset = test_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### Model Architecture & Training

# %%
from tensorflow.keras.layers import Input, Conv2D, Add, MaxPooling2D, Concatenate, BatchNormalization, Activation, Conv2DTranspose, SpatialDropout2D
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

def conv_block(inputs, num_filters):
    # Shortcut path
    shortcut = inputs
    
    # Adjust shortcut dimensions if needed
    shortcut = Conv2D(num_filters, (1, 1), padding='same', kernel_regularizer=l2(0.001))(shortcut)
    shortcut = BatchNormalization()(shortcut)
    
    # Residual path
    x = Conv2D(num_filters, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001))(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    x = Conv2D(num_filters, (3, 3), activation=None, padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    
    # Add shortcut to the residual path
    x = Add()([x, shortcut])
    x = Activation("relu")(x)
    
    return x
def encoder_block(inputs, drop_out, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPooling2D((2, 2))(x)
    p = SpatialDropout2D(drop_out)(p)
    
    return x, p
def decoder_block(inputs, skip, num_filters):
    x = Conv2DTranspose(num_filters, (2,2), strides = 2, padding='same')(inputs)
    x = Concatenate()([x, skip])
    x = conv_block(x ,num_filters)
    
    return x
def unet_model(input_shape):
    inputs = Input(shape=input_shape)

    # Encoder
    s0, p0 = encoder_block(inputs, 0.1, 12)
    s1, p1 = encoder_block(p0, 0.1, 32)
    s2, p2 = encoder_block(p1, 0.1, 64)
    s3, p3 = encoder_block(p2, 0.2, 128)
    s4, p4 = encoder_block(p3, 0.2, 128)
    
    # Bridge
    b1 = conv_block(p4, 256)
    
    # Decoder
    d1 = decoder_block(b1, s4, 128)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)
    d5 = decoder_block(d4, s0, 32)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(d5)

    model = Model(inputs=[inputs], outputs=[outputs])
    return model
# Instantiate the model
input_shape = (128, 128, 12)  
model = unet_model(input_shape)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │      1,308 │ input_layer[0][0] │
# │                     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         48 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      1,308 │ activation[0][0]  │
# │                     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        156 │ input_layer[0][0] │
# │                     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         48 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │         48 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 12)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ add[0][0]         │
# │ (Activation)        │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d   │ (None, 64, 64,    │          0 │ max_pooling2d[0]… │
# │ (SpatialDropout2D)  │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │      3,488 │ spatial_dropout2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │      9,248 │ activation_2[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │        416 │ spatial_dropout2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 64, 64,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_1 │ (None, 32, 32,    │          0 │ max_pooling2d_1[… │
# │ (SpatialDropout2D)  │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │     18,496 │ spatial_dropout2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │     36,928 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │      2,112 │ spatial_dropout2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_2 │ (None, 16, 16,    │          0 │ max_pooling2d_2[… │
# │ (SpatialDropout2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │     73,856 │ spatial_dropout2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │    147,584 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │      8,320 │ spatial_dropout2… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 16, 16,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 128) │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_3 │ (None, 8, 8, 128) │          0 │ max_pooling2d_3[… │
# │ (SpatialDropout2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 8, 8, 128) │    147,584 │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 8, 8, 128) │    147,584 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 8, 8, 128) │     16,512 │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 8, 8, 128) │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 4, 4, 128) │          0 │ activation_9[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_4 │ (None, 4, 4, 128) │          0 │ max_pooling2d_4[… │
# │ (SpatialDropout2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 4, 4, 256) │    295,168 │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 4, 4, 256) │    590,080 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 4, 4, 256) │     33,024 │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 4, 4, 256) │          0 │ add_5[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 128) │    131,200 │ activation_11[0]… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 8, 8, 256) │          0 │ conv2d_transpose… │
# │ (Concatenate)       │                   │            │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 8, 8, 128) │    295,040 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 8, 8, 128) │    147,584 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 8, 8, 128) │     32,896 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 8, 8, 128) │          0 │ add_6[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │     65,664 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 16, 16,    │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 16, 16,    │    147,584 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 16, 16,    │     32,896 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 16, 16,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 32, 32,    │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 32, 32,    │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 32, 32,    │      8,256 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 32, 32,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │      8,224 │ activation_17[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 64, 64,    │     18,464 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 64, 64,    │      9,248 │ activation_18[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 64, 64,    │      2,080 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 64, 64,    │          0 │ add_9[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │      4,128 │ activation_19[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 44)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 128, 128,  │     12,704 │ concatenate_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │      9,248 │ activation_20[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │      1,440 │ concatenate_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 128, 128,  │          0 │ add_10[0][0]      │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │         33 │ activation_21[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,910,501 (11.10 MB)
#  Trainable params: 2,904,477 (11.08 MB)
#  Non-trainable params: 6,024 (23.53 KB)

# %%
def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)  

    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = (intersection + smooth) / (union + smooth)
    return iou


def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)  # Apply threshold

    y_true = tf.reshape(y_true, [-1])  # Flatten
    y_pred = tf.reshape(y_pred, [-1])

    intersection = tf.reduce_sum(y_true * y_pred)
    dice = (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    return dice

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss="binary_crossentropy", metrics=[iou_metric, dice_coefficient])

# %%
# Set up early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',   
    patience=7,          
    restore_best_weights=True 
)

# %%
# ModelCheckpoint: Save the model after every epoch.
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'segmodel.weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True
)

# %%
# ReduceLROnPlateau
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',   
    factor=0.5,     
    patience=3,          
    min_lr=1e-6, 
)

# %%
# Train the model
history = model.fit(
    train_dataset, 
    validation_data=val_dataset, 
    epochs=50, 
    callbacks=[early_stopping, reduce_lr_on_plateau, checkpoint]
)
# Out:
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 33s 445ms/step - dice_coefficient: 0.5175 - iou_metric: 0.3721 - loss: 2.8846 - val_dice_coefficient: 0.4122 - val_iou_metric: 0.2651 - val_loss: 1.6568 - learning_rate: 0.0010
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 448ms/step - dice_coefficient: 0.7211 - iou_metric: 0.5691 - loss: 1.2228 - val_dice_coefficient: 2.3594e-11 - val_iou_metric: 2.3594e-11 - val_loss: 1.1981 - learning_rate: 0.0010
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 442ms/step - dice_coefficient: 0.7655 - iou_metric: 0.6345 - loss: 0.7904 - val_dice_coefficient: 2.3594e-11 - val_iou_metric: 2.3594e-11 - val_loss: 1.0488 - learning_rate: 0.0010
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 462ms/step - dice_coefficient: 0.7647 - iou_metric: 0.6282 - loss: 0.6326 - val_dice_coefficient: 2.3594e-11 - val_iou_metric: 2.3594e-11 - val_loss: 0.9681 - learning_rate: 0.0010
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 455ms/step - dice_coefficient: 0.7932 - iou_metric: 0.6659 - loss: 0.5348 - val_dice_coefficient: 0.0028 - val_iou_metric: 0.0014 - val_loss: 0.9269 - learning_rate: 0.0010
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 472ms/step - dice_coefficient: 0.8021 - iou_metric: 0.6751 - loss: 0.4588 - val_dice_coefficient: 0.3987 - val_iou_metric: 0.2539 - val_loss: 0.7958 - learning_rate: 0.0010
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 455ms/step - dice_coefficient: 0.8025 - iou_metric: 0.6780 - loss: 0.4587 - val_dice_coefficient: 0.4424 - val_iou_metric: 0.2898 - val_loss: 0.7279 - learning_rate: 0.0010
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 455ms/step - dice_coefficient: 0.7725 - iou_metric: 0.6399 - loss: 0.4403 - val_dice_coefficient: 0.4194 - val_iou_metric: 0.2705 - val_loss: 0.6439 - learning_rate: 0.0010
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 453ms/step - dice_coefficient: 0.7876 - iou_metric: 0.6585 - loss: 0.3906 - val_dice_coefficient: 0.6049 - val_iou_metric: 0.4396 - val_loss: 0.5782 - learning_rate: 0.0010
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 462ms/step - dice_coefficient: 0.7741 - iou_metric: 0.6401 - loss: 0.3888 - val_dice_coefficient: 0.7920 - val_iou_metric: 0.6623 - val_loss: 0.4473 - learning_rate: 0.0010
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 456ms/step - dice_coefficient: 0.7992 - iou_metric: 0.6739 - loss: 0.3599 - val_dice_coefficient: 0.7599 - val_iou_metric: 0.6175 - val_loss: 0.4441 - learning_rate: 0.0010
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 470ms/step - dice_coefficient: 0.7879 - iou_metric: 0.6614 - loss: 0.3599 - val_dice_coefficient: 0.7262 - val_iou_metric: 0.5754 - val_loss: 0.4384 - learning_rate: 0.0010
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 462ms/step - dice_coefficient: 0.7900 - iou_metric: 0.6601 - loss: 0.3334 - val_dice_coefficient: 0.7358 - val_iou_metric: 0.5863 - val_loss: 0.4308 - learning_rate: 0.0010
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 456ms/step - dice_coefficient: 0.7750 - iou_metric: 0.6401 - loss: 0.3530 - val_dice_coefficient: 0.8136 - val_iou_metric: 0.6911 - val_loss: 0.3859 - learning_rate: 0.0010
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - dice_coefficient: 0.7767 - iou_metric: 0.6439 - loss: 0.3423 - val_dice_coefficient: 0.7095 - val_iou_metric: 0.5548 - val_loss: 0.4619 - learning_rate: 0.0010
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 410ms/step - dice_coefficient: 0.7672 - iou_metric: 0.6294 - loss: 0.3558 - val_dice_coefficient: 0.7096 - val_iou_metric: 0.5546 - val_loss: 0.4577 - learning_rate: 0.0010
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 478ms/step - dice_coefficient: 0.8122 - iou_metric: 0.6926 - loss: 0.3119 - val_dice_coefficient: 0.8356 - val_iou_metric: 0.7232 - val_loss: 0.3263 - learning_rate: 0.0010
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 389ms/step - dice_coefficient: 0.8016 - iou_metric: 0.6741 - loss: 0.3196 - val_dice_coefficient: 0.8357 - val_iou_metric: 0.7230 - val_loss: 0.3383 - learning_rate: 0.0010
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 402ms/step - dice_coefficient: 0.7619 - iou_metric: 0.6240 - loss: 0.3171 - val_dice_coefficient: 0.7996 - val_iou_metric: 0.6691 - val_loss: 0.3382 - learning_rate: 0.0010
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 498ms/step - dice_coefficient: 0.7925 - iou_metric: 0.6650 - loss: 0.3180 - val_dice_coefficient: 0.8340 - val_iou_metric: 0.7201 - val_loss: 0.3041 - learning_rate: 0.0010
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 393ms/step - dice_coefficient: 0.7960 - iou_metric: 0.6721 - loss: 0.2787 - val_dice_coefficient: 0.8355 - val_iou_metric: 0.7232 - val_loss: 0.3079 - learning_rate: 0.0010
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 402ms/step - dice_coefficient: 0.7966 - iou_metric: 0.6667 - loss: 0.3091 - val_dice_coefficient: 0.8544 - val_iou_metric: 0.7510 - val_loss: 0.3052 - learning_rate: 0.0010
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 410ms/step - dice_coefficient: 0.7778 - iou_metric: 0.6464 - loss: 0.2839 - val_dice_coefficient: 0.8633 - val_iou_metric: 0.7643 - val_loss: 0.3690 - learning_rate: 0.0010
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 485ms/step - dice_coefficient: 0.7930 - iou_metric: 0.6670 - loss: 0.2859 - val_dice_coefficient: 0.8735 - val_iou_metric: 0.7800 - val_loss: 0.2793 - learning_rate: 5.0000e-04
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 398ms/step - dice_coefficient: 0.8142 - iou_metric: 0.6950 - loss: 0.2648 - val_dice_coefficient: 0.8468 - val_iou_metric: 0.7389 - val_loss: 0.2829 - learning_rate: 5.0000e-04
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 407ms/step - dice_coefficient: 0.8166 - iou_metric: 0.6965 - loss: 0.2561 - val_dice_coefficient: 0.8693 - val_iou_metric: 0.7728 - val_loss: 0.2912 - learning_rate: 5.0000e-04
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 481ms/step - dice_coefficient: 0.8221 - iou_metric: 0.7032 - loss: 0.2529 - val_dice_coefficient: 0.8874 - val_iou_metric: 0.8005 - val_loss: 0.2643 - learning_rate: 5.0000e-04
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 454ms/step - dice_coefficient: 0.8141 - iou_metric: 0.6937 - loss: 0.2739 - val_dice_coefficient: 0.8550 - val_iou_metric: 0.7513 - val_loss: 0.2587 - learning_rate: 5.0000e-04
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 399ms/step - dice_coefficient: 0.8207 - iou_metric: 0.7030 - loss: 0.2487 - val_dice_coefficient: 0.8497 - val_iou_metric: 0.7425 - val_loss: 0.2736 - learning_rate: 5.0000e-04
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 402ms/step - dice_coefficient: 0.7734 - iou_metric: 0.6469 - loss: 0.2784 - val_dice_coefficient: 0.8409 - val_iou_metric: 0.7291 - val_loss: 0.2871 - learning_rate: 5.0000e-04
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 470ms/step - dice_coefficient: 0.7712 - iou_metric: 0.6373 - loss: 0.2623 - val_dice_coefficient: 0.8732 - val_iou_metric: 0.7780 - val_loss: 0.2470 - learning_rate: 5.0000e-04
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 394ms/step - dice_coefficient: 0.8214 - iou_metric: 0.7045 - loss: 0.2657 - val_dice_coefficient: 0.8490 - val_iou_metric: 0.7428 - val_loss: 0.3006 - learning_rate: 5.0000e-04
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 414ms/step - dice_coefficient: 0.7946 - iou_metric: 0.6681 - loss: 0.2708 - val_dice_coefficient: 0.8690 - val_iou_metric: 0.7721 - val_loss: 0.2579 - learning_rate: 5.0000e-04
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 401ms/step - dice_coefficient: 0.8315 - iou_metric: 0.7175 - loss: 0.2533 - val_dice_coefficient: 0.8891 - val_iou_metric: 0.8029 - val_loss: 0.2621 - learning_rate: 5.0000e-04
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 402ms/step - dice_coefficient: 0.8331 - iou_metric: 0.7210 - loss: 0.2541 - val_dice_coefficient: 0.8799 - val_iou_metric: 0.7889 - val_loss: 0.2600 - learning_rate: 2.5000e-04
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 489ms/step - dice_coefficient: 0.8223 - iou_metric: 0.7063 - loss: 0.2417 - val_dice_coefficient: 0.8809 - val_iou_metric: 0.7897 - val_loss: 0.2399 - learning_rate: 2.5000e-04
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 421ms/step - dice_coefficient: 0.8315 - iou_metric: 0.7170 - loss: 0.2639 - val_dice_coefficient: 0.8790 - val_iou_metric: 0.7869 - val_loss: 0.2465 - learning_rate: 2.5000e-04
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 478ms/step - dice_coefficient: 0.8337 - iou_metric: 0.7214 - loss: 0.2598 - val_dice_coefficient: 0.8847 - val_iou_metric: 0.7957 - val_loss: 0.2345 - learning_rate: 2.5000e-04
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 410ms/step - dice_coefficient: 0.8093 - iou_metric: 0.6881 - loss: 0.2463 - val_dice_coefficient: 0.8807 - val_iou_metric: 0.7895 - val_loss: 0.2409 - learning_rate: 2.5000e-04
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 417ms/step - dice_coefficient: 0.8452 - iou_metric: 0.7398 - loss: 0.2429 - val_dice_coefficient: 0.8804 - val_iou_metric: 0.7888 - val_loss: 0.2368 - learning_rate: 2.5000e-04
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 479ms/step - dice_coefficient: 0.8420 - iou_metric: 0.7334 - loss: 0.2328 - val_dice_coefficient: 0.8924 - val_iou_metric: 0.8080 - val_loss: 0.2272 - learning_rate: 2.5000e-04
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 404ms/step - dice_coefficient: 0.8301 - iou_metric: 0.7163 - loss: 0.2426 - val_dice_coefficient: 0.8752 - val_iou_metric: 0.7809 - val_loss: 0.2380 - learning_rate: 2.5000e-04
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 409ms/step - dice_coefficient: 0.8256 - iou_metric: 0.7077 - loss: 0.2509 - val_dice_coefficient: 0.8850 - val_iou_metric: 0.7964 - val_loss: 0.2359 - learning_rate: 2.5000e-04
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 405ms/step - dice_coefficient: 0.8427 - iou_metric: 0.7340 - loss: 0.2459 - val_dice_coefficient: 0.8760 - val_iou_metric: 0.7822 - val_loss: 0.2389 - learning_rate: 2.5000e-04
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 470ms/step - dice_coefficient: 0.8259 - iou_metric: 0.7107 - loss: 0.2298 - val_dice_coefficient: 0.8934 - val_iou_metric: 0.8092 - val_loss: 0.2267 - learning_rate: 1.2500e-04
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 409ms/step - dice_coefficient: 0.8345 - iou_metric: 0.7244 - loss: 0.2336 - val_dice_coefficient: 0.8866 - val_iou_metric: 0.7986 - val_loss: 0.2274 - learning_rate: 1.2500e-04
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 12s 403ms/step - dice_coefficient: 0.8198 - iou_metric: 0.7051 - loss: 0.2475 - val_dice_coefficient: 0.8859 - val_iou_metric: 0.7975 - val_loss: 0.2279 - learning_rate: 1.2500e-04
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 13s 410ms/step - dice_coefficient: 0.8348 - iou_metric: 0.7231 - loss: 0.2310 - val_dice_coefficient: 0.8818 - val_iou_metric: 0.7908 - val_loss: 0.2292 - learning_rate: 1.2500e-04
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 15s 480ms/step - dice_coefficient: 0.8435 - iou_metric: 0.7322 - loss: 0.2418 - val_dice_coefficient: 0.8901 - val_iou_metric: 0.8040 - val_loss: 0.2200 - learning_rate: 6.2500e-05
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 14s 459ms/step - dice_coefficient: 0.8564 - iou_metric: 0.7535 - loss: 0.2133 - val_dice_coefficient: 0.8930 - val_iou_metric: 0.8087 - val_loss: 0.2168 - learning_rate: 6.2500e-05

# %%
# function to plot loss

def plot_loss( loss, val_loss, epochs):
    
    plt.figure()
    plt.figure(figsize=(10,5))
    plt.plot(epochs, loss, 'b', label='Training Loss')
    plt.plot(epochs, val_loss, 'y', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc=0)
    plt.show()

# %%
model_history = history.history

loss = model_history['loss']

val_loss = model_history['val_loss']

epochs = history.epoch

plot_loss(loss, val_loss, epochs)

# %% [markdown]
# ### model evaluation

# %%
# Evaluate model
val_loss, val_iou_metric, val_dice_coefficient = model.evaluate(val_dataset)
print(f"Validation IOU: {val_iou_metric:.4f}")
print(f"Validation Dice Coefficient: {val_dice_coefficient:.4f}")
print(f"Validation loss: {val_loss:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - dice_coefficient: 0.8817 - iou_metric: 0.7910 - loss: 0.2297
# Validation IOU: 0.8087
# Validation Dice Coefficient: 0.8930
# Validation loss: 0.2168

# %%
# Save the Model
model.save("water_segmentation_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model= load_model("water_segmentation_model.h5", compile= False)

# %%
#evaluate on test set
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# Predict on the test set
y_pred = model.predict(test_dataset)
y_true= test_labels

test_iou= iou_metric(y_true, y_pred)
print(f"IoU: {test_iou:.4f}")

test_dice= dice_coefficient(y_true, y_pred)
print(f"Dice: {test_dice:.4f}")

# Calculate Precision, Recall, and F1-Score 
threshold = 0.5
y_pred_binary = (y_pred > threshold).astype(int)  

# Flatten arrays
y_true_flat = y_true.flatten()
y_pred_flat = y_pred_binary.flatten()

precision = precision_score(y_true_flat, y_pred_flat)
recall = recall_score(y_true_flat, y_pred_flat)
f1 = f1_score(y_true_flat, y_pred_flat)

print(f"Precision: {precision :.4f}, Recall: {recall :.4f}, F1-Score: {f1 :.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# IoU: 0.7298
# Dice: 0.8438
# Precision: 0.9314, Recall: 0.7712, F1-Score: 0.8438

# %%
import matplotlib.pyplot as plt

model= load_model("water_segmentation_model.h5", compile= False)

num_samples = 10
sample_indices = np.random.choice(len(test_images), num_samples, replace=False)
sample_images = test_images[sample_indices]  # RGB images
sample_masks = test_labels[sample_indices]   # Ground truth masks
predicted_masks = model.predict(sample_images)  # Predicted masks

# Convert predicted masks to binary using a threshold
threshold = 0.5
predicted_masks_binary = (predicted_masks > threshold).astype(int)

# Plot results
fig, axes = plt.subplots(num_samples, 3, figsize=(12, num_samples * 4))

for i in range(num_samples):
    axes[i, 0].imshow(sample_images[i][:, :,[3, 2, 1]])  # RGB image
    axes[i, 0].set_title("RGB Image")
    axes[i, 0].axis("off")

    axes[i, 1].imshow(sample_masks[i].squeeze(), cmap="gray")  # Ground truth mask
    axes[i, 1].set_title("Ground Truth Mask")
    axes[i, 1].axis("off")

    axes[i, 2].imshow(predicted_masks_binary[i].squeeze(), cmap="gray")  # Predicted mask
    axes[i, 2].set_title("Predicted Mask")
    axes[i, 2].axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
